# %% [markdown]
# # About Dataset
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria, namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attributes and 1 output attribute (class)
# The 244 instances have been classified into fire (138 classes) and not fire (106 classes) classes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Algerian_forest_fires_dataset.csv")
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.shape
# Out:
# (247, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# # Cleaning the dataset
#
# # Checking for missing values

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# We can label the dataset into region as given by default.That is, from 123th index we have our region 2 (Sidi-Bel Abbes Region).

# %%
df.loc[:122, "Region"] = 0
df.loc[122:, "Region"] = 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN     1.0
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN     1.0
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN     1.0

# %%
df=df.dropna().reset_index(drop=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  , Region]
# Index: []

# %%
df['Region'] = df['Region'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       244 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.7+ KB

# %%
df.shape
# Out:
# (244, 15)

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
#Here there are some spaces in the column names...so we try to remove them for better.
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# # Change the data type as required based on the dataset

# %%
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']] = df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %% [markdown]
# # See the stat description here now

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %% [markdown]
# # EDA and Feature Engineering

# %%
# Save the cleaned dataset to a csv
df.to_csv('/content/Algerian_forest_fires_cleaned_dataset.csv',index= False)

# %%
# We are not focusing on the classes since our focus is to predict FWI (regressio)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
# Here we can see that there are trailling spaces so ,there are many variations. Thus we cannot use == , rather we use the contains func to map.
df.Classes.value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
#drop day,month,year since it is not that much needed
df_clean = df.drop(['day','month','year'],axis=1)

# %%
df_clean.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Encode the classes as 0 and 1

df_clean['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df_clean.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_clean.Classes.value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
#plot density plot for all features
plt.style.use('seaborn-v0_8')
df_clean.hist(bins=50,figsize=(20,15))
plt.show()

# %%
# Displaying the percentage of classes
perct = df_clean.Classes.value_counts(normalize=True)*100
perct
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
#plot the percentage in a pie chart
label= ['Fire','Not Fire']
plt.pie(perct,labels=label,autopct='%1.1f%%',startangle=90)
plt.title("Percentage of Classes")
plt.show()

# %% [markdown]
# To find the correlation between the features

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df_clean.corr(),annot=True,fmt='.2f')
plt.show()

# %%
# Box plot of the target
sns.boxplot(df_clean['FWI'])
# Out:
# <Axes: ylabel='FWI'>

# %%
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),"not fire","fire")

# %%
df1= df.loc[df['Region']==0]
sns.countplot(x='month',hue='Classes',data=df1)
plt.title('Region 1')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
df2= df.loc[df['Region']==1]
sns.countplot(x='month',hue='Classes',data=df2)
plt.title('Region 2')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # We can see from the plots that a large number of fires occured in Aug and July the most for both the regions
#
# #Less fire was mostly on sept

# %% [markdown]
# # Feature selection and scaling

# %%
df_clean.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
X = df_clean.drop('FWI',axis=1)
y = df_clean['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
#Now we need to split the train/test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (182, 11)
# (61, 11)
# (182,)
# (61,)

# %%
#Check for multicolinearility
plt.figure(figsize=(12,7))
sns.heatmap(X_train.corr(),annot=True,fmt='.2f')
plt.show()

# %%
def correlation_above_threshold(df,threshold):
  col_corr = set()
  corr_matrix = df.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j]) > threshold:
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
# THreshold may be given by the domain expert or set by urself if u have the domain knowledge
to_remove = correlation_above_threshold(X_train,0.85)

# %%
X_train.drop(to_remove,axis=1,inplace=True)
X_test.drop(to_remove,axis=1,inplace=True)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %% [markdown]
# Feature Scaling (Standardization)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(X_train)
plt.subplot(1,2,2)
sns.boxplot(X_train_scaled)
plt.show()

# %% [markdown]
# # Model training

# %%
#Linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
model = LinearRegression()
model.fit(X_train_scaled,y_train)
y_pred = model.predict(X_test_scaled)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  0.6742766873791607
# R2 Score:  0.9847657384266951

# %%
#Lasso regression model
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error,r2_score
model = Lasso()
model.fit(X_train_scaled,y_train)
y_pred = model.predict(X_test_scaled)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  2.2483458918974772
# R2 Score:  0.9492020263112388

# %%
#Ridge regression model
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,r2_score
model = Ridge()
model.fit(X_train_scaled,y_train)
y_pred = model.predict(X_test_scaled)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  0.6949198918152074
# R2 Score:  0.9842993364555513

# %%
#ElasticNet regression model
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
model = ElasticNet()
model.fit(X_train_scaled,y_train)
y_pred = model.predict(X_test_scaled)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  5.5172511010252245
# R2 Score:  0.8753460589519703

# %% [markdown]
# # Using Statsmodel finding the significant features that contribute to the prediction

# %%
import statsmodels.api as sm
X_train_sm = sm.add_constant(X_train_scaled)  # add intercept
model2 = sm.OLS(y_train,X_train_sm).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    FWI   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     616.0
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):          7.01e-126
# Time:                        10:04:16   Log-Likelihood:                -310.05
# No. Observations:                 182   AIC:                             640.1
# Df Residuals:                     172   BIC:                             672.1
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1560      0.101     70.602      0.000       6.956       7.356
# ...

# %%
#checked the p-values from statsmodels OLS summary. Features x1–x4 were not significant (p>0.05)

# %%
sig_idx = [4,5,6,7,8]
X_train_sig = X_train_scaled[:, sig_idx]
X_train_sig = sm.add_constant(X_train_sig)  # add intercept
model2 = sm.OLS(y_train,X_train_sig).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    FWI   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     1128.
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):          1.25e-131
# Time:                        10:09:24   Log-Likelihood:                -310.56
# No. Observations:                 182   AIC:                             633.1
# Df Residuals:                     176   BIC:                             652.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1560      0.100     71.220      0.000       6.958       7.354
# ...

# %% [markdown]
# # Applying the Regression only for the significant features

# %%
#Linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
model = LinearRegression()
sig_idx = [4,5,6,7,8]
X_train_sig = X_train_scaled[:, sig_idx]
model.fit(X_train_sig,y_train)
X_test_sig = X_test_scaled[:, sig_idx]
y_pred = model.predict(X_test_sig)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  0.6569498010586771
# R2 Score:  0.9851572132075943

# %%
#Ridge regression model
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,r2_score
model = Ridge()
sig_idx = [4,5,6,7,8]
X_train_sig = X_train_scaled[:, sig_idx]
model.fit(X_train_sig,y_train)
X_test_sig = X_test_scaled[:, sig_idx]
y_pred = model.predict(X_test_sig)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  0.6779962132672305
# R2 Score:  0.9846817013668825

# %%
#Lasso regression model
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error,r2_score
model = Lasso()
sig_idx = [4,5,6,7,8]
X_train_sig = X_train_scaled[:, sig_idx]
model.fit(X_train_sig,y_train)
X_test_sig = X_test_scaled[:, sig_idx]
y_pred = model.predict(X_test_sig)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  2.248384072858117
# R2 Score:  0.9492011636702008

# %%
#ElasticNet regression model
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
model = ElasticNet()
sig_idx = [4,5,6,7,8]
X_train_sig = X_train_scaled[:, sig_idx]
model.fit(X_train_sig,y_train)
X_test_sig = X_test_scaled[:, sig_idx]
y_pred = model.predict(X_test_sig)
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# MSE:  5.19769861259333
# R2 Score:  0.8825658639464065
